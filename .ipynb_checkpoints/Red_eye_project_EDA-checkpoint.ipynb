# %%
# import libraries
import pandas as pd
import numpy as np

import matplotlib, matplotlib.pyplot as plt
import seaborn as sns

# %%
rowdata_df = pd.read_csv("../pharmacy_tx.csv")

# %%
print(rowdata_df.shape)
rowdata_df.head(10)
# Out:
# (13910244, 9)
#       tx_date      pharmacy diagnosis                   drug     bin      pcn  \
# 0  2022-01-02   Pharmacy #6    G99.93     branded tanoclolol  725700     1UQC
# 1  2022-01-02  Pharmacy #42    U60.52       branded oxasoted  664344      NaN
# 2  2022-01-02  Pharmacy #37    Q85.91      branded cupitelol  725700     1UQC
# 3  2022-01-02  Pharmacy #30    U60.52       generic oxasoted  571569    KB38N
# 4  2022-01-02  Pharmacy #18    N55.01         branded mamate  664344      NaN
# 5  2022-01-02  Pharmacy #19    K32.86          branded lalol   96934  S76J7V6
# 6  2022-01-02  Pharmacy #19    U60.52     branded foxivelule  725700   327CKV
# 7  2022-01-02  Pharmacy #27    U27.71     generic foxivelule  539437      NaN
# 8  2022-01-02  Pharmacy #48    K32.86  generic tafistitrisin  322463      NaN
# 9  2022-01-02  Pharmacy #28    I68.27       branded prazinib  664344   CS8580
#
#           group  rejected  patient_pay
# 0           NaN     False        13.39
# 1   52H8KH0F83K     False         7.02
# 2           NaN     False        13.39
# 3        6BYJBW     False        10.84
# 4       ZX2QUWR     False        47.00
# 5           NaN     False        13.93
# 6  IOEAN1DWVV3Y     False        11.15
# 7         1CAHL     False         7.27
# 8       HO8HUGL     False         6.01
# 9           NaN     False        11.74

# %%
rowdata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13910244 entries, 0 to 13910243
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   tx_date      object
#  1   pharmacy     object
#  2   diagnosis    object
#  3   drug         object
#  4   bin          int64
#  5   pcn          object
#  6   group        object
#  7   rejected     bool
#  8   patient_pay  float64
# dtypes: bool(1), float64(1), int64(1), object(6)
# memory usage: 862.3+ MB

# %%
#rowdata_dropna_df=rowdata_df.dropna()
print(rowdata_df.shape)
# Out:
# (13910244, 9)

# %%
duplicate = rowdata_df[rowdata_df.duplicated(["pharmacy","bin"])]

# %%
duplicate.head(6)
print(duplicate.shape)
# Out:
# (13909548, 9)

# %%
# drop duplicates if all columns matched
dropduplicate_df= rowdata_df.drop_duplicates()

# %%
dropduplicate_df
# Out:
#              tx_date      pharmacy diagnosis                   drug     bin  \
# 0         2022-01-02   Pharmacy #6    G99.93     branded tanoclolol  725700
# 1         2022-01-02  Pharmacy #42    U60.52       branded oxasoted  664344
# 2         2022-01-02  Pharmacy #37    Q85.91      branded cupitelol  725700
# 3         2022-01-02  Pharmacy #30    U60.52       generic oxasoted  571569
# 4         2022-01-02  Pharmacy #18    N55.01         branded mamate  664344
# ...              ...           ...       ...                    ...     ...
# 13910239  2022-12-30  Pharmacy #42    U27.71     branded colifunene  322463
# 13910240  2022-12-30  Pharmacy #45    N59.44  generic tafistitrisin  664344
# 13910241  2022-12-30  Pharmacy #54    W50.87     generic tanoclolol  691847
# 13910242  2022-12-30   Pharmacy #0    I68.27       branded prazinib   96934
# 13910243  2022-12-30  Pharmacy #46    G99.93        branded bovirol  322463
#
#               pcn        group  rejected  patient_pay
# 0            1UQC          NaN     False        13.39
# 1             NaN  52H8KH0F83K     False         7.02
# 2            1UQC          NaN     False        13.39
# 3           KB38N       6BYJBW     False        10.84
# 4             NaN      ZX2QUWR     False        47.00
# ...           ...          ...       ...          ...
# 13910239      NaN      HO8HUGL      True         0.00
# 13910240      NaN    TFZOR5R49     False         6.28
# 13910241   N098KI       6SP1DG     False         6.94
# 13910242  S76J7V6          NaN     False        13.93
# 13910243  3O71UTS          NaN     False        12.22
#
# [12561845 rows x 9 columns]

# %%
dropduplicate_df.groupby(["rejected"]).count()
# Out:
#            tx_date  pharmacy  diagnosis      drug       bin      pcn    group  \
# rejected
# False     11512008  11512008   11512008  11512008  11512008  8581198  8268435
# True       1049837   1049837    1049837   1049837   1049837   757422   769773
#
#           patient_pay
# rejected
# False        11512008
# True          1049837

# %%
# drop the rejected claims
#df_filtered = dropduplicate_df[dropduplicate_df['rejected'] == False]

# %%
dropduplicate_df[['brand', 'drug_name']] =dropduplicate_df.drug.str.split(expand=True)
# Out:
# /Users/dilhumarablat/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/frame.py:3188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
dropduplicate_df.drop(["drug"], axis =1, inplace =True)
# Out:
# /Users/dilhumarablat/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/frame.py:4312: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
dropduplicate_df.head()
print(dropduplicate_df.shape)
# Out:
# (12561845, 10)

# %%
dropduplicate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12561845 entries, 0 to 13910243
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   tx_date      object
#  1   pharmacy     object
#  2   diagnosis    object
#  3   bin          int64
#  4   pcn          object
#  5   group        object
#  6   rejected     bool
#  7   patient_pay  float64
#  8   brand        object
#  9   drug_name    object
# dtypes: bool(1), float64(1), int64(1), object(7)
# memory usage: 970.4+ MB

# %%
# removing the claims in Janurary
NoJan_df = dropduplicate_df[dropduplicate_df['tx_date'] >= "2022-02-01"]

# %%
print(NoJan_df.shape)
NoJan_df.head()
# Out:
# (11629192, 10)
#             tx_date      pharmacy diagnosis     bin      pcn        group  \
# 1019813  2022-02-01  Pharmacy #54    G51.87  691847    XH4T3       GOM8K0
# 1019814  2022-02-01   Pharmacy #7    K32.86  322463   3Y5ZW0          NaN
# 1019815  2022-02-01  Pharmacy #42    G99.93  691847     2TIC  XK8RM5E75ZW
# 1019816  2022-02-01  Pharmacy #24    D13.25  160389    RB7UU     RS5RB3YA
# 1019817  2022-02-01  Pharmacy #12    U60.52  322463  3O71UTS          NaN
#
#          rejected  patient_pay    brand      drug_name
# 1019813     False        10.72  generic       prazinib
# 1019814     False        18.16  branded     tanoclolol
# 1019815     False         8.73  generic        simarol
# 1019816     False        72.22  branded  plazamiglutic
# 1019817     False        12.22  generic       oxasoted

# %%
NoJan_df.columns.tolist()
# Out:
# ['tx_date',
#  'pharmacy',
#  'diagnosis',
#  'bin',
#  'pcn',
#  'group',
#  'rejected',
#  'patient_pay',
#  'brand',
#  'drug_name']

# %%
# getting columns contains strings
df_str_columns=NoJan_df.select_dtypes(include=['object'])
for col in df_str_columns.columns:
    print(col)
# Out:
# tx_date
# pharmacy
# diagnosis
# pcn
# group
# brand
# drug_name

# %%
# Initial imports
from collections import Counter
from pathlib import Path
import plotly.express as px
# Import dependencies
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from seaborn import set_style
set_style("whitegrid")

# %%
df_pharmacy=NoJan_df.groupby(["pharmacy"]).count()
pharmacy=df_pharmacy.reset_index()

# %%
## bar plot for pharmacy claims 
plt.figure(figsize=(10,6))
pharmacy_sorted = pharmacy.sort_values('tx_date')
sns.barplot(data = pharmacy_sorted,
               y = 'tx_date',
               x = 'pharmacy')

plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

plt.ylabel('Number of claims', fontsize=16)
plt.xlabel('pharmacy', fontsize=16)

plt.show()

# %%
pcn=NoJan_df.groupby(["pcn"]).count()
pcn=pcn.reset_index()
pcn
# Out:
#         pcn  tx_date  pharmacy  diagnosis     bin   group  rejected  \
# 0      1UQC   545323    545323     545323  545323       0    545323
# 1      2TIC    91876     91876      91876   91876   91876     91876
# 2    327CKV   828881    828881     828881  828881  828881    828881
# 3      393U    26449     26449      26449   26449   26449     26449
# 4   3O71UTS   553824    553824     553824  553824       0    553824
# 5    3Y5ZW0   113573    113573     113573  113573       0    113573
# 6   6ZGS97C    94224     94224      94224   94224       0     94224
# 7    7THOQ5   154760    154760     154760  154760       0    154760
# 8   9C5MOR3    89998     89998      89998   89998   89998     89998
# 9      9D24    84470     84470      84470   84470   84470     84470
# 10    9FU70    75074     75074      75074   75074   75074     75074
# 11   AZUO5U    61885     61885      61885   61885   61885     61885
# 12     BIZF    91033     91033      91033   91033   91033     91033
# 13   BZ22Z2    42051     42051      42051   42051   42051     42051
# 14   CG3ZWQ    23052     23052      23052   23052       0     23052
# 15   CS8580   263755    263755     263755  263755       0    263755
# 16     DY4B   208222    208222     208222  208222       0    208222
# 17     FX2Z    18554     18554      18554   18554   18554     18554
# 18    IF448   131401    131401     131401  131401  131401    131401
# 19    J5DT8   223514    223514     223514  223514  223514    223514
# 20  K5KDJ7G    19309     19309      19309   19309   19309     19309
# 21    KB38N   485411    485411     485411  485411  485411    485411
# 22    KBOSN    96956     96956      96956   96956       0     96956
# 23  MQWH09H    30466     30466      30466   30466   30466     30466
# 24   MSCXSG   570881    570881     570881  570881  570881    570881
# 25   N098KI   338710    338710     338710  338710  338710    338710
# 26    NC7EN   299189    299189     299189  299189       0    299189
# 27    NG4CS    30273     30273      30273   30273   30273     30273
# 28     OO0E    54750     54750      54750   54750   54750     54750
# 29     P4LC    41981     41981      41981   41981   41981     41981
# 30    RAM3J    43809     43809      43809   43809   43809     43809
# 31    RB7UU   227896    227896     227896  227896  227896    227896
# 32   REGLCC   139070    139070     139070  139070  139070    139070
# 33    RM0HB   139567    139567     139567  139567  139567    139567
# 34  S76J7V6   615679    615679     615679  615679       0    615679
# 35   T17LNK   161743    161743     161743  161743  161743    161743
# 36    T52GV   310773    310773     310773  310773  310773    310773
# 37    TAZ5W   143788    143788     143788  143788  143788    143788
# 38     TPJD   198058    198058     198058  198058       0    198058
# 39    ULM7G    27627     27627      27627   27627       0     27627
# 40   W1LW9Y   100058    100058     100058  100058  100058    100058
# 41     W7L3    36615     36615      36615   36615   36615     36615
# 42     WM6A   237319    237319     237319  237319  237319    237319
# 43    XH4T3    83586     83586      83586   83586   83586     83586
# 44    YFVIA   252564    252564     252564  252564  252564    252564
# 45   YICC41   118331    118331     118331  118331  118331    118331
# 46   YL5CMT    31730     31730      31730   31730       0     31730
# 47     ZQPX    87002     87002      87002   87002   87002     87002
#
#     patient_pay   brand  drug_name
# 0        545323  545323     545323
# 1         91876   91876      91876
# 2        828881  828881     828881
# 3         26449   26449      26449
# 4        553824  553824     553824
# 5        113573  113573     113573
# 6         94224   94224      94224
# 7        154760  154760     154760
# 8         89998   89998      89998
# 9         84470   84470      84470
# 10        75074   75074      75074
# 11        61885   61885      61885
# 12        91033   91033      91033
# 13        42051   42051      42051
# 14        23052   23052      23052
# 15       263755  263755     263755
# 16       208222  208222     208222
# 17        18554   18554      18554
# 18       131401  131401     131401
# 19       223514  223514     223514
# 20        19309   19309      19309
# 21       485411  485411     485411
# 22        96956   96956      96956
# 23        30466   30466      30466
# 24       570881  570881     570881
# 25       338710  338710     338710
# 26       299189  299189     299189
# 27        30273   30273      30273
# 28        54750   54750      54750
# 29        41981   41981      41981
# 30        43809   43809      43809
# 31       227896  227896     227896
# 32       139070  139070     139070
# 33       139567  139567     139567
# 34       615679  615679     615679
# 35       161743  161743     161743
# 36       310773  310773     310773
# 37       143788  143788     143788
# 38       198058  198058     198058
# 39        27627   27627      27627
# 40       100058  100058     100058
# 41        36615   36615      36615
# 42       237319  237319     237319
# 43        83586   83586      83586
# 44       252564  252564     252564
# 45       118331  118331     118331
# 46        31730   31730      31730
# 47        87002   87002      87002

# %%
## bar plot for pharmacy claims 
plt.figure(figsize=(12,6))
pcn_sorted = pcn.sort_values('tx_date')
sns.barplot(data = pcn_sorted,
               y = 'tx_date',
               x = 'pcn')

plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

plt.ylabel('Number of claims', fontsize=16)
plt.xlabel('pcn', fontsize=16)
plt.xticks(rotation = 90)


plt.show()

# %%
group=NoJan_df.groupby(["group"]).count()
group=group.reset_index()
group.head()
# Out:
#          group  tx_date  pharmacy  diagnosis     bin     pcn  rejected  \
# 0        0OGKQ   100058    100058     100058  100058  100058    100058
# 1   0TZ9XYJZJH    68460     68460      68460   68460       0     68460
# 2        1CAHL   371065    371065     371065  371065       0    371065
# 3       1N5IRQ    19309     19309      19309   19309   19309     19309
# 4  52H8KH0F83K   421897    421897     421897  421897       0    421897
#
#    patient_pay   brand  drug_name
# 0       100058  100058     100058
# 1        68460   68460      68460
# 2       371065  371065     371065
# 3        19309   19309      19309
# 4       421897  421897     421897

# %%
## bar plot for pharmacy claims 
plt.figure(figsize=(12,6))
group_sorted = group.sort_values('tx_date')
sns.barplot(data = group_sorted,
               y = 'tx_date',
               x = 'group')

plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

plt.ylabel('Number of claims', fontsize=16)
plt.xlabel('group', fontsize=16)
plt.xticks(rotation = 90)



plt.show()

# %%
# using lableEncoder to assign brand and rejected into numerical values 
le = LabelEncoder()
NoJan_df1 = NoJan_df.copy()
NoJan_df1['brand'] = le.fit_transform(NoJan_df1['brand'])
NoJan_df1['rejected'] = le.fit_transform(NoJan_df1['rejected'])

# %%
NoJan_df1.head()
# Out:
#             tx_date      pharmacy diagnosis     bin      pcn        group  \
# 1019813  2022-02-01  Pharmacy #54    G51.87  691847    XH4T3       GOM8K0
# 1019814  2022-02-01   Pharmacy #7    K32.86  322463   3Y5ZW0          NaN
# 1019815  2022-02-01  Pharmacy #42    G99.93  691847     2TIC  XK8RM5E75ZW
# 1019816  2022-02-01  Pharmacy #24    D13.25  160389    RB7UU     RS5RB3YA
# 1019817  2022-02-01  Pharmacy #12    U60.52  322463  3O71UTS          NaN
#
#          rejected  patient_pay  brand      drug_name
# 1019813         0        10.72      1       prazinib
# 1019814         0        18.16      0     tanoclolol
# 1019815         0         8.73      1        simarol
# 1019816         0        72.22      0  plazamiglutic
# 1019817         0        12.22      1       oxasoted

# %%
# Create our features and get dummies
X = pd.get_dummies(NoJan_df1, columns= ["pharmacy", "diagnosis", "pcn","group", 
                                 "drug_name"]).drop(["rejected","tx_date"],axis=1)

# Create our target
y = NoJan_df1['rejected']
X.head()
# Out:
#             bin  patient_pay  brand  pharmacy_Pharmacy #0  \
# 1019813  691847        10.72      1                     0
# 1019814  322463        18.16      0                     0
# 1019815  691847         8.73      1                     0
# 1019816  160389        72.22      0                     0
# 1019817  322463        12.22      1                     0
#
#          pharmacy_Pharmacy #1  pharmacy_Pharmacy #10  pharmacy_Pharmacy #11  \
# 1019813                     0                      0                      0
# 1019814                     0                      0                      0
# 1019815                     0                      0                      0
# 1019816                     0                      0                      0
# 1019817                     0                      0                      0
#
#          pharmacy_Pharmacy #12  pharmacy_Pharmacy #13  pharmacy_Pharmacy #14  \
# 1019813                      0                      0                      0
# 1019814                      0                      0                      0
# 1019815                      0                      0                      0
# 1019816                      0                      0                      0
# 1019817                      1                      0                      0
#
#          ...  drug_name_tanoclolol  drug_name_thiostasteglume  \
# 1019813  ...                     0                          0
# 1019814  ...                     1                          0
# 1019815  ...                     0                          0
# 1019816  ...                     0                          0
# 1019817  ...                     0                          0
#
#          drug_name_tocilic  drug_name_tocrocin  drug_name_todiadianic  \
# 1019813                  0                   0                      0
# 1019814                  0                   0                      0
# 1019815                  0                   0                      0
# 1019816                  0                   0                      0
# 1019817                  0                   0                      0
#
#          drug_name_tovane  drug_name_tricatripride  drug_name_tugesutin  \
# 1019813                 0                        0                    0
# 1019814                 0                        0                    0
# 1019815                 0                        0                    0
# 1019816                 0                        0                    0
# 1019817                 0                        0                    0
#
#          drug_name_vivafastat  drug_name_vocopirin
# 1019813                     0                    0
# 1019814                     0                    0
# 1019815                     0                    0
# 1019816                     0                    0
# 1019817                     0                    0
#
# [5 rows x 367 columns]

# %%
NoJan_df1
# Out:
#              tx_date      pharmacy diagnosis     bin      pcn        group  \
# 1019813   2022-02-01  Pharmacy #54    G51.87  691847    XH4T3       GOM8K0
# 1019814   2022-02-01   Pharmacy #7    K32.86  322463   3Y5ZW0          NaN
# 1019815   2022-02-01  Pharmacy #42    G99.93  691847     2TIC  XK8RM5E75ZW
# 1019816   2022-02-01  Pharmacy #24    D13.25  160389    RB7UU     RS5RB3YA
# 1019817   2022-02-01  Pharmacy #12    U60.52  322463  3O71UTS          NaN
# ...              ...           ...       ...     ...      ...          ...
# 13910239  2022-12-30  Pharmacy #42    U27.71  322463      NaN      HO8HUGL
# 13910240  2022-12-30  Pharmacy #45    N59.44  664344      NaN    TFZOR5R49
# 13910241  2022-12-30  Pharmacy #54    W50.87  691847   N098KI       6SP1DG
# 13910242  2022-12-30   Pharmacy #0    I68.27   96934  S76J7V6          NaN
# 13910243  2022-12-30  Pharmacy #46    G99.93  322463  3O71UTS          NaN
#
#           rejected  patient_pay  brand      drug_name
# 1019813          0        10.72      1       prazinib
# 1019814          0        18.16      0     tanoclolol
# 1019815          0         8.73      1        simarol
# 1019816          0        72.22      0  plazamiglutic
# 1019817          0        12.22      1       oxasoted
# ...            ...          ...    ...            ...
# 13910239         1         0.00      0     colifunene
# 13910240         0         6.28      1  tafistitrisin
# 13910241         0         6.94      1     tanoclolol
# 13910242         0        13.93      0       prazinib
# 13910243         0        12.22      0        bovirol
#
# [11629192 rows x 10 columns]

# %%
NoJan_df1.describe()
# Out:
#                 bin      rejected   patient_pay         brand
# count  1.162919e+07  1.162919e+07  1.162919e+07  1.162919e+07
# mean   5.756403e+05  8.365620e-02  2.440255e+01  3.691248e-01
# std    2.037136e+05  2.768715e-01  4.051599e+01  4.825678e-01
# min    9.693400e+04  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.224630e+05  0.000000e+00  8.510000e+00  0.000000e+00
# 50%    6.643440e+05  0.000000e+00  1.339000e+01  0.000000e+00
# 75%    7.183500e+05  0.000000e+00  1.891000e+01  1.000000e+00
# max    9.569710e+05  1.000000e+00  5.579300e+02  1.000000e+00

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# 0    10656338
# 1      972854
# Name: rejected, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1,  train_size=0.25)

# %%
# Check balances
print(Counter(y_train))
print(Counter(y_test))
# Out:
# Counter({0: 2664575, 1: 242723})
# Counter({0: 7991763, 1: 730131})

# %%
# Resample the training data with the BalancedRandomForestClassifier
# get time for execustion
from datetime import datetime
start_time = datetime.now()

from imblearn.ensemble import BalancedRandomForestClassifier
BalancedRFC_model = BalancedRandomForestClassifier(n_estimators=100, random_state=1)
BalancedRFC_model= BalancedRFC_model.fit(X_train, y_train)

end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Duration: 1:30:58.297391

# %%
# Calculated the balanced accuracy score
y_pred = BalancedRFC_model.predict(X_test)
from sklearn.metrics import balanced_accuracy_score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0      7991763            0
# Actual 1            0       730131

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      1.00      1.00      1.00      1.00      1.00   7991763
#           1       1.00      1.00      1.00      1.00      1.00      1.00    730131
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00   8721894

# %%
# List the features 
features = BalancedRFC_model.feature_importances_
features
# Out:
# array([1.55863057e-03, 7.13678843e-01, 8.14394521e-02, 8.49846738e-05,
#        9.30206506e-05, 7.82254672e-05, 9.19165371e-05, 8.49144996e-05,
#        8.14736513e-05, 9.06749784e-05, 8.38764373e-05, 9.16117649e-05,
#        8.06158596e-05, 8.65394588e-05, 8.47533340e-05, 8.35585608e-05,
#        8.77855113e-05, 8.63473887e-05, 8.00528212e-05, 8.58634236e-05,
#        9.07404659e-05, 8.60797423e-05, 8.06139684e-05, 8.53439694e-05,
#        9.17336644e-05, 8.53744208e-05, 8.51430446e-05, 8.59822559e-05,
#        8.08000286e-05, 8.22717767e-05, 8.19291871e-05, 7.52903737e-05,
#        8.43671899e-05, 9.09784832e-05, 8.39916806e-05, 8.00940618e-05,
#        8.74010131e-05, 8.25527871e-05, 8.42291043e-05, 8.62193077e-05,
#        8.10370570e-05, 8.07241367e-05, 9.16984431e-05, 7.86550908e-05,
#        8.66688544e-05, 8.55295293e-05, 8.42334613e-05, 8.72001931e-05,
#        8.78815813e-05, 8.48316616e-05, 8.13279096e-05, 8.57214389e-05,
#        9.17791829e-05, 8.18352053e-05, 8.81612683e-05, 7.99953646e-05,
#        7.77850361e-05, 8.17989842e-05, 8.04798638e-05, 8.66790048e-05,
#        8.89798492e-05, 2.03807371e-10, 1.37807939e-06, 3.72143504e-06,
#        6.03801561e-08, 6.18936156e-07, 1.06089928e-05, 4.60842681e-05,
#        2.56260672e-06, 7.43024365e-04, 1.53238226e-06, 1.11337082e-05,
#        5.85736773e-05, 0.00000000e+00, 1.13865985e-05, 4.66740622e-07,
#        3.29713444e-06, 3.70604971e-07, 9.90751521e-06, 4.82387083e-07,
#        6.20591194e-07, 7.73168365e-07, 2.09252977e-04, 4.86457657e-04,
#        8.48710168e-07, 1.07808715e-05, 8.60125528e-05, 2.20012222e-05,
#        0.00000000e+00, 7.34772222e-08, 1.10206671e-06, 6.07419797e-08,
#        4.66072510e-07, 5.68855903e-07, 1.70479817e-08, 5.41200363e-04,
#        8.03135463e-07, 1.23942563e-05, 1.29894944e-02, 1.01562023e-06,
#        2.44192287e-07, 1.03524277e-05, 4.55976642e-04, 5.08914004e-06,
#        3.06308689e-06, 1.43209532e-06, 5.09484905e-05, 3.24571171e-05,
#        2.32024137e-07, 5.08730592e-10, 5.04949640e-05, 7.38579827e-08,
#        2.09883124e-04, 5.44064458e-03, 2.92717965e-06, 8.97014646e-07,
#        2.18179628e-06, 0.00000000e+00, 1.61879519e-02, 1.39736688e-06,
#        4.25457847e-04, 1.78639436e-06, 7.04140775e-07, 5.31060795e-06,
#        5.37750661e-05, 4.83434011e-04, 6.63972664e-08, 1.01136444e-06,
#        4.76694615e-04, 0.00000000e+00, 2.06041636e-06, 0.00000000e+00,
#        8.66306784e-06, 0.00000000e+00, 1.51381308e-05, 6.63161027e-06,
#        4.44698357e-06, 6.10349396e-07, 3.40640789e-05, 8.84006586e-05,
#        1.59618161e-04, 1.16235675e-06, 3.29596351e-08, 3.89679291e-05,
#        5.45619007e-07, 1.44211887e-05, 2.50255394e-08, 4.27541292e-04,
#        6.20923536e-05, 1.73513199e-05, 4.34839557e-03, 1.84877438e-04,
#        2.03004289e-07, 2.35572713e-05, 1.19244383e-07, 9.45397915e-07,
#        2.54619629e-05, 1.91080724e-07, 2.41687078e-07, 1.35863834e-05,
#        0.00000000e+00, 1.17075732e-04, 5.20771821e-04, 1.28019065e-03,
#        7.89739916e-05, 1.13660998e-05, 1.25788614e-07, 1.48171991e-07,
#        3.42666011e-04, 1.75491503e-06, 2.82079562e-04, 1.16343398e-06,
#        2.23671178e-07, 2.53521352e-07, 3.44333589e-06, 1.85894629e-06,
#        6.81769060e-03, 9.54735433e-08, 3.23743648e-06, 0.00000000e+00,
#        3.64808099e-06, 1.04021912e-06, 1.83241604e-04, 0.00000000e+00,
#        4.75068830e-04, 3.81246260e-05, 2.35748777e-06, 0.00000000e+00,
#        1.01793611e-03, 1.57250689e-04, 6.27810665e-06, 4.79544430e-03,
#        2.04638381e-06, 2.92937124e-05, 2.28884640e-04, 9.59611278e-05,
#        1.96319812e-04, 2.01589653e-05, 4.12687013e-04, 1.09841695e-04,
#        1.42322628e-04, 8.85277044e-05, 2.13265748e-05, 1.15861822e-04,
#        7.30234913e-05, 5.91354954e-05, 2.99428033e-05, 2.07851090e-05,
#        1.69715255e-05, 1.12971690e-04, 2.07666617e-04, 1.26805153e-05,
#        5.29348866e-05, 6.06325608e-05, 9.91235362e-06, 2.53008117e-04,
#        4.32784930e-05, 1.60873385e-05, 1.56367967e-04, 1.40884218e-04,
#        1.14236389e-04, 1.21132347e-05, 3.65701037e-05, 2.86693115e-05,
#        1.52205901e-05, 1.10420675e-04, 1.14894786e-04, 1.46241495e-04,
#        2.80166391e-04, 1.38107533e-04, 1.59484808e-04, 1.05759063e-04,
#        1.32201761e-04, 2.52420537e-05, 1.20607110e-04, 3.13499292e-05,
#        1.80766597e-04, 3.46199027e-05, 1.63661732e-04, 6.68663668e-05,
#        2.65298713e-05, 3.77290950e-05, 1.15892305e-04, 5.67652390e-05,
#        2.31682062e-04, 8.51813863e-06, 3.80751511e-04, 2.59754052e-04,
#        1.43983070e-04, 1.18406946e-05, 2.59153044e-05, 3.25046720e-05,
#        1.48679818e-05, 3.56836597e-05, 1.75587077e-04, 1.13254932e-04,
#        1.79557442e-04, 2.08878314e-04, 1.25722381e-04, 5.35189221e-05,
#        3.11915444e-05, 1.22239201e-05, 1.07849818e-03, 2.16831188e-05,
#        4.92394351e-05, 4.97872273e-05, 2.23304845e-04, 6.01392726e-05,
#        3.18982272e-05, 1.88028599e-04, 7.27410396e-05, 3.44016309e-05,
#        9.23200813e-06, 2.82170061e-05, 7.16529805e-05, 1.20979883e-04,
#        2.68478400e-05, 1.21688316e-04, 2.67624192e-04, 1.11977939e-04,
#        3.76009648e-05, 1.08809978e-04, 2.45869932e-05, 1.09068449e-04,
#        8.71782020e-05, 1.85949593e-05, 1.40606970e-04, 1.39345774e-04,
#        1.98949989e-05, 9.91228843e-05, 4.32546159e-03, 6.73354085e-04,
#        2.50754517e-04, 1.36299527e-03, 1.17239809e-03, 8.20400870e-04,
#        1.07899480e-03, 8.41050274e-05, 3.18039035e-03, 1.73377141e-04,
#        4.02487146e-04, 1.13803633e-04, 7.73338348e-06, 2.20943989e-03,
#        4.12516455e-03, 1.86018199e-06, 5.15713187e-04, 3.76874780e-04,
#        3.61567014e-04, 7.71413253e-03, 4.25904212e-05, 6.06460440e-06,
#        2.36379297e-04, 1.73497932e-03, 3.87772710e-04, 4.59446151e-03,
#        1.68619571e-06, 1.87995163e-03, 6.16229751e-05, 1.12759697e-02,
#        4.98011493e-04, 4.68198715e-04, 2.97620191e-04, 1.16151152e-05,
#        2.39352591e-04, 2.45426669e-03, 2.71142242e-07, 3.63993389e-04,
#        2.71628242e-06, 3.31022025e-05, 1.29894822e-03, 1.18707171e-04,
#        7.17648645e-03, 2.25929916e-06, 8.29469898e-04, 3.81519676e-05,
#        3.76776182e-04, 2.19629416e-03, 3.95878666e-03, 7.51592408e-06,
#        2.15457408e-03, 3.89318495e-06, 2.67330268e-02, 1.34247479e-04,
#        1.69092266e-03, 5.65103270e-04, 8.53248500e-05, 8.38802015e-03,
#        6.13801704e-05, 2.05125948e-04, 1.42037650e-03, 7.01103389e-04,
#        1.06437747e-05, 6.15420027e-04, 3.08387934e-06, 1.76613049e-03,
#        9.14118518e-04, 4.46288567e-03, 5.85038115e-05, 5.51342889e-04,
#        6.49265370e-06, 5.20850699e-04, 4.63728601e-03, 3.09058437e-05,
#        1.14140484e-03, 3.08949458e-04, 5.08249565e-04])

# %%
importances = pd.DataFrame(np.zeros((X_train.shape[1], 1)), columns=["importance"], index=X_train.columns)

importances.iloc[:,0] = BalancedRFC_model.feature_importances_

importances = importances.sort_values(by="importance", ascending=False)[:40]

plt.figure(figsize=(15, 10))
sns.barplot(x="importance", y=importances.index, data=importances)
plt.show()
plt.savefig("featureimportance.png") #save as png

# %%
NoJan_df1['log_patient_pay'] = np.log10(NoJan_df1['patient_pay'])
# Out:
# /Users/dilhumarablat/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/arraylike.py:274: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
NoJan_df1.groupby(["log_patient_pay"]).count()
# Out:
#                  tx_date  pharmacy  diagnosis     bin     pcn   group  \
# log_patient_pay
# -inf              972854    972854     972854  972854  701839  713537
#  0.531479           1844      1844       1844    1844    1844       0
#  0.537819          17319     17319      17319   17319    1614   17319
#  0.540329           7439      7439       7439    7439    7439    7439
#  0.544068          10454     10454      10454   10454    1831   10454
# ...                  ...       ...        ...     ...     ...     ...
#  2.746424              7         7          7       7       7       7
#  2.746479              6         6          6       6       6       6
#  2.746486             15        15         15      15      15      15
#  2.746525             23        23         23      23      23      23
#  2.746580              2         2          2       2       2       2
#
#                  rejected  patient_pay   brand  drug_name
# log_patient_pay
# -inf               972854       972854  972854     972854
#  0.531479            1844         1844    1844       1844
#  0.537819           17319        17319   17319      17319
#  0.540329            7439         7439    7439       7439
#  0.544068           10454        10454   10454      10454
# ...                   ...          ...     ...        ...
#  2.746424               7            7       7          7
#  2.746479               6            6       6          6
#  2.746486              15           15      15         15
#  2.746525              23           23      23         23
#  2.746580               2            2       2          2
#
# [20436 rows x 10 columns]

# %%
NoJan_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11629192 entries, 1019813 to 13910243
# Data columns (total 11 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   tx_date          object
#  1   pharmacy         object
#  2   diagnosis        object
#  3   bin              int64
#  4   pcn              object
#  5   group            object
#  6   rejected         int64
#  7   patient_pay      float64
#  8   brand            int64
#  9   drug_name        object
#  10  log_patient_pay  float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 1.0+ GB

# %%
NoJan_df1['log_patient_pay']=NoJan_df1['log_patient_pay'].astype(str)

# %%
df_filtered = NoJan_df1[NoJan_df1['log_patient_pay'] != "-inf"]

# %%
df_filtered
# Out:
#              tx_date      pharmacy diagnosis     bin      pcn        group  \
# 1019813   2022-02-01  Pharmacy #54    G51.87  691847    XH4T3       GOM8K0
# 1019814   2022-02-01   Pharmacy #7    K32.86  322463   3Y5ZW0          NaN
# 1019815   2022-02-01  Pharmacy #42    G99.93  691847     2TIC  XK8RM5E75ZW
# 1019816   2022-02-01  Pharmacy #24    D13.25  160389    RB7UU     RS5RB3YA
# 1019817   2022-02-01  Pharmacy #12    U60.52  322463  3O71UTS          NaN
# ...              ...           ...       ...     ...      ...          ...
# 13910238  2022-12-30  Pharmacy #39    Q72.66  571569    KB38N       6BYJBW
# 13910240  2022-12-30  Pharmacy #45    N59.44  664344      NaN    TFZOR5R49
# 13910241  2022-12-30  Pharmacy #54    W50.87  691847   N098KI       6SP1DG
# 13910242  2022-12-30   Pharmacy #0    I68.27   96934  S76J7V6          NaN
# 13910243  2022-12-30  Pharmacy #46    G99.93  322463  3O71UTS          NaN
#
#           rejected  patient_pay  brand      drug_name     log_patient_pay
# 1019813          0        10.72      1       prazinib  1.0301947853567512
# 1019814          0        18.16      0     tanoclolol  1.2591158441850663
# 1019815          0         8.73      1        simarol  0.9410142437055697
# 1019816          0        72.22      0  plazamiglutic  1.8586574840908079
# 1019817          0        12.22      1       oxasoted  1.0870712059065355
# ...            ...          ...    ...            ...                 ...
# 13910238         0        66.47      0    momudobatin  1.8226256787741408
# 13910240         0         6.28      1  tafistitrisin  0.7979596437371962
# 13910241         0         6.94      1     tanoclolol  0.8413594704548549
# 13910242         0        13.93      0       prazinib  1.1439511164239635
# 13910243         0        12.22      0        bovirol  1.0870712059065355
#
# [10656338 rows x 11 columns]

# %%
df_filtered.groupby(["log_patient_pay"]).count()
# Out:
#                     tx_date  pharmacy  diagnosis    bin   pcn  group  \
# log_patient_pay
# 0.5314789170422551     1844      1844       1844   1844  1844      0
# 0.5378190950732742    17319     17319      17319  17319  1614  17319
# 0.5403294747908738     7439      7439       7439   7439  7439   7439
# 0.5440680443502757    10454     10454      10454  10454  1831  10454
# 0.6020599913279624     1531      1531       1531   1531  1531   1531
# ...                     ...       ...        ...    ...   ...    ...
# 2.7464240055890037        7         7          7      7     7      7
# 2.746478509930031         6         6          6      6     6      6
# 2.7464862957060983       15        15         15     15    15     15
# 2.7465252224928896       23        23         23     23    23     23
# 2.7465797141333828        2         2          2      2     2      2
#
#                     rejected  patient_pay  brand  drug_name
# log_patient_pay
# 0.5314789170422551      1844         1844   1844       1844
# 0.5378190950732742     17319        17319  17319      17319
# 0.5403294747908738      7439         7439   7439       7439
# 0.5440680443502757     10454        10454  10454      10454
# 0.6020599913279624      1531         1531   1531       1531
# ...                      ...          ...    ...        ...
# 2.7464240055890037         7            7      7          7
# 2.746478509930031          6            6      6          6
# 2.7464862957060983        15           15     15         15
# 2.7465252224928896        23           23     23         23
# 2.7465797141333828         2            2      2          2
#
# [20435 rows x 10 columns]

# %%
df_filtered['log_patient_pay']=df_filtered['log_patient_pay'].astype(float).round(1)
# Out:
# /Users/dilhumarablat/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_filtered.groupby(["log_patient_pay"]).count()
# Out:
#                  tx_date  pharmacy  diagnosis      bin      pcn    group  \
# log_patient_pay
# 0.5                37056     37056      37056    37056    12728    35212
# 0.6                38933     38933      38933    38933    16619    37100
# 0.7               246902    246902     246902   246902   128321   211026
# 0.8              1097322   1097322    1097322  1097322   711559   868651
# 0.9               623635    623635     623635   623635   454806   414183
# 1.0              1838466   1838466    1838466  1838466  1230310  1526050
# 1.1              1471248   1471248    1471248  1471248  1255124   739378
# 1.2              1853336   1853336    1853336  1853336  1358923  1570906
# 1.3              1208861   1208861    1208861  1208861   974218   744035
# 1.4               397256    397256     397256   397256   305526   252045
# 1.5               199943    199943     199943   199943   151009   137760
# 1.6               227582    227582     227582   227582   184990   151472
# 1.7               223003    223003     223003   223003   191093   154682
# 1.8               284521    284521     284521   284521   235644   205912
# 1.9               253139    253139     253139   253139   198959   167133
# 2.0               211340    211340     211340   211340   159787   146454
# 2.1                78259     78259      78259    78259    66914    51158
# 2.2               228463    228463     228463   228463   195267   147524
# 2.3                69315     69315      69315    69315    56533    47674
# 2.4                34055     34055      34055    34055    27768    22073
# 2.5                12081     12081      12081    12081     9470     9305
# 2.6                 3565      3565       3565     3565     3265     2244
# 2.7                18057     18057      18057    18057    14388    12893
#
#                  rejected  patient_pay    brand  drug_name
# log_patient_pay
# 0.5                 37056        37056    37056      37056
# 0.6                 38933        38933    38933      38933
# 0.7                246902       246902   246902     246902
# 0.8               1097322      1097322  1097322    1097322
# 0.9                623635       623635   623635     623635
# 1.0               1838466      1838466  1838466    1838466
# 1.1               1471248      1471248  1471248    1471248
# 1.2               1853336      1853336  1853336    1853336
# 1.3               1208861      1208861  1208861    1208861
# 1.4                397256       397256   397256     397256
# 1.5                199943       199943   199943     199943
# 1.6                227582       227582   227582     227582
# 1.7                223003       223003   223003     223003
# 1.8                284521       284521   284521     284521
# 1.9                253139       253139   253139     253139
# 2.0                211340       211340   211340     211340
# 2.1                 78259        78259    78259      78259
# 2.2                228463       228463   228463     228463
# 2.3                 69315        69315    69315      69315
# 2.4                 34055        34055    34055      34055
# 2.5                 12081        12081    12081      12081
# 2.6                  3565         3565     3565       3565
# 2.7                 18057        18057    18057      18057

# %%
df_filtered["log_patient_pay"].plot.hist(bins =20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
boxplot =df_filtered.boxplot(column=['log_patient_pay'])

# %%
df_filtered1 =df_filtered.copy()

# %%
df_filtered1['log_patient_pay']=df_filtered1['log_patient_pay'].astype(float).round(2)

# %%
data =df_filtered1[["log_patient_pay"]]
counts, edges, bars = plt.hist(data)
#              ^

plt.bar_label(bars)
# Out:
# [Text(0, 0, '322891'),
#  Text(0, 0, '1.72096e+06'),
#  Text(0, 0, '3.30971e+06'),
#  Text(0, 0, '3.0622e+06'),
#  Text(0, 0, '597199'),
#  Text(0, 0, '735106'),
#  Text(0, 0, '464479'),
#  Text(0, 0, '306722'),
#  Text(0, 0, '103370'),
#  Text(0, 0, '33703')]

# %%
df_filtered1.loc[df_filtered1["patient_pay"]<=10]
# Out:
#              tx_date      pharmacy diagnosis     bin     pcn         group  \
# 1019815   2022-02-01  Pharmacy #42    G99.93  691847    2TIC   XK8RM5E75ZW
# 1019819   2022-02-01  Pharmacy #37    Y11.84  691847   NC7EN           NaN
# 1019822   2022-02-01  Pharmacy #50    K32.86  664344     NaN   52H8KH0F83K
# 1019823   2022-02-01  Pharmacy #30    K32.86  322463   T52GV        EVD4X5
# 1019824   2022-02-01  Pharmacy #52    G99.93  322463     NaN       HO8HUGL
# ...              ...           ...       ...     ...     ...           ...
# 13910231  2022-12-30   Pharmacy #5    K32.86  664344    BIZF     QK6BI1N61
# 13910233  2022-12-30  Pharmacy #12    G99.93  160389   RB7UU      RS5RB3YA
# 13910234  2022-12-30  Pharmacy #54    T57.97  664344     NaN  STGRDKR1J5RD
# 13910240  2022-12-30  Pharmacy #45    N59.44  664344     NaN     TFZOR5R49
# 13910241  2022-12-30  Pharmacy #54    W50.87  691847  N098KI        6SP1DG
#
#           rejected  patient_pay  brand      drug_name  log_patient_pay
# 1019815          0         8.73      1        simarol              0.9
# 1019819          0         9.49      1         tovane              1.0
# 1019822          0         6.74      0     tanoclolol              0.8
# 1019823          0         8.97      1      pucomalol              1.0
# 1019824          0         4.58      1       rulfalol              0.7
# ...            ...          ...    ...            ...              ...
# 13910231         0         6.36      1     tanoclolol              0.8
# 13910233         0         5.32      1       rulfalol              0.7
# 13910234         0         5.95      1     foxivelule              0.8
# 13910240         0         6.28      1  tafistitrisin              0.8
# 13910241         0         6.94      1     tanoclolol              0.8
#
# [2436174 rows x 11 columns]

# %%
df_filtered1.loc[df_filtered1["patient_pay"]<=20]
# Out:
#              tx_date      pharmacy diagnosis     bin      pcn        group  \
# 1019813   2022-02-01  Pharmacy #54    G51.87  691847    XH4T3       GOM8K0
# 1019814   2022-02-01   Pharmacy #7    K32.86  322463   3Y5ZW0          NaN
# 1019815   2022-02-01  Pharmacy #42    G99.93  691847     2TIC  XK8RM5E75ZW
# 1019817   2022-02-01  Pharmacy #12    U60.52  322463  3O71UTS          NaN
# 1019818   2022-02-01  Pharmacy #11    Q85.91  664344     TPJD          NaN
# ...              ...           ...       ...     ...      ...          ...
# 13910237  2022-12-30  Pharmacy #42    U61.13  664344     TPJD          NaN
# 13910240  2022-12-30  Pharmacy #45    N59.44  664344      NaN    TFZOR5R49
# 13910241  2022-12-30  Pharmacy #54    W50.87  691847   N098KI       6SP1DG
# 13910242  2022-12-30   Pharmacy #0    I68.27   96934  S76J7V6          NaN
# 13910243  2022-12-30  Pharmacy #46    G99.93  322463  3O71UTS          NaN
#
#           rejected  patient_pay  brand        drug_name  log_patient_pay
# 1019813          0        10.72      1         prazinib              1.0
# 1019814          0        18.16      0       tanoclolol              1.3
# 1019815          0         8.73      1          simarol              0.9
# 1019817          0        12.22      1         oxasoted              1.1
# 1019818          0        19.82      0  glycontazepelol              1.3
# ...            ...          ...    ...              ...              ...
# 13910237         0        19.22      1            ratin              1.3
# 13910240         0         6.28      1    tafistitrisin              0.8
# 13910241         0         6.94      1       tanoclolol              0.8
# 13910242         0        13.93      0         prazinib              1.1
# 13910243         0        12.22      0          bovirol              1.1
#
# [8116538 rows x 11 columns]

# %%
df_filtered1.loc[df_filtered1["patient_pay"]<=30]
# Out:
#              tx_date      pharmacy diagnosis     bin      pcn        group  \
# 1019813   2022-02-01  Pharmacy #54    G51.87  691847    XH4T3       GOM8K0
# 1019814   2022-02-01   Pharmacy #7    K32.86  322463   3Y5ZW0          NaN
# 1019815   2022-02-01  Pharmacy #42    G99.93  691847     2TIC  XK8RM5E75ZW
# 1019817   2022-02-01  Pharmacy #12    U60.52  322463  3O71UTS          NaN
# 1019818   2022-02-01  Pharmacy #11    Q85.91  664344     TPJD          NaN
# ...              ...           ...       ...     ...      ...          ...
# 13910237  2022-12-30  Pharmacy #42    U61.13  664344     TPJD          NaN
# 13910240  2022-12-30  Pharmacy #45    N59.44  664344      NaN    TFZOR5R49
# 13910241  2022-12-30  Pharmacy #54    W50.87  691847   N098KI       6SP1DG
# 13910242  2022-12-30   Pharmacy #0    I68.27   96934  S76J7V6          NaN
# 13910243  2022-12-30  Pharmacy #46    G99.93  322463  3O71UTS          NaN
#
#           rejected  patient_pay  brand        drug_name  log_patient_pay
# 1019813          0        10.72      1         prazinib              1.0
# 1019814          0        18.16      0       tanoclolol              1.3
# 1019815          0         8.73      1          simarol              0.9
# 1019817          0        12.22      1         oxasoted              1.1
# 1019818          0        19.82      0  glycontazepelol              1.3
# ...            ...          ...    ...              ...              ...
# 13910237         0        19.22      1            ratin              1.3
# 13910240         0         6.28      1    tafistitrisin              0.8
# 13910241         0         6.94      1       tanoclolol              0.8
# 13910242         0        13.93      0         prazinib              1.1
# 13910243         0        12.22      0          bovirol              1.1
#
# [8866826 rows x 11 columns]

# %%
df_filtered1.loc[df_filtered1["patient_pay"]<=50]
# Out:
#              tx_date      pharmacy diagnosis     bin      pcn        group  \
# 1019813   2022-02-01  Pharmacy #54    G51.87  691847    XH4T3       GOM8K0
# 1019814   2022-02-01   Pharmacy #7    K32.86  322463   3Y5ZW0          NaN
# 1019815   2022-02-01  Pharmacy #42    G99.93  691847     2TIC  XK8RM5E75ZW
# 1019817   2022-02-01  Pharmacy #12    U60.52  322463  3O71UTS          NaN
# 1019818   2022-02-01  Pharmacy #11    Q85.91  664344     TPJD          NaN
# ...              ...           ...       ...     ...      ...          ...
# 13910237  2022-12-30  Pharmacy #42    U61.13  664344     TPJD          NaN
# 13910240  2022-12-30  Pharmacy #45    N59.44  664344      NaN    TFZOR5R49
# 13910241  2022-12-30  Pharmacy #54    W50.87  691847   N098KI       6SP1DG
# 13910242  2022-12-30   Pharmacy #0    I68.27   96934  S76J7V6          NaN
# 13910243  2022-12-30  Pharmacy #46    G99.93  322463  3O71UTS          NaN
#
#           rejected  patient_pay  brand        drug_name  log_patient_pay
# 1019813          0        10.72      1         prazinib              1.0
# 1019814          0        18.16      0       tanoclolol              1.3
# 1019815          0         8.73      1          simarol              0.9
# 1019817          0        12.22      1         oxasoted              1.1
# 1019818          0        19.82      0  glycontazepelol              1.3
# ...            ...          ...    ...              ...              ...
# 13910237         0        19.22      1            ratin              1.3
# 13910240         0         6.28      1    tafistitrisin              0.8
# 13910241         0         6.94      1       tanoclolol              0.8
# 13910242         0        13.93      0         prazinib              1.1
# 13910243         0        12.22      0          bovirol              1.1
#
# [9325049 rows x 11 columns]

# %%
df_filtered1.loc[df_filtered1["patient_pay"]>500]
# Out:
#              tx_date      pharmacy diagnosis     bin     pcn         group  \
# 1022828   2022-02-01  Pharmacy #40    B45.03  725700  327CKV  IOEAN1DWVV3Y
# 1023175   2022-02-01  Pharmacy #55    B45.03  664344     NaN  STGRDKR1J5RD
# 1024390   2022-02-01   Pharmacy #6    U75.95  664344     NaN  YY6B1J4E8KJ3
# 1024658   2022-02-01  Pharmacy #54    B45.03  725700  327CKV  IOEAN1DWVV3Y
# 1025257   2022-02-01  Pharmacy #52    U75.95  691847  N098KI        6SP1DG
# ...              ...           ...       ...     ...     ...           ...
# 13901386  2022-12-28  Pharmacy #55    B45.03  664344     NaN  STGRDKR1J5RD
# 13904984  2022-12-29   Pharmacy #9    B45.03  725700  327CKV  IOEAN1DWVV3Y
# 13906108  2022-12-29  Pharmacy #26    U75.95  725700  327CKV  IOEAN1DWVV3Y
# 13909780  2022-12-30  Pharmacy #33    B45.03  664344  W1LW9Y         0OGKQ
# 13909851  2022-12-30  Pharmacy #20    U75.95  691847  N098KI        6SP1DG
#
#           rejected  patient_pay  brand    drug_name  log_patient_pay
# 1022828          0       507.84      0  monemodiase              2.7
# 1023175          0       507.21      0  monemodiase              2.7
# 1024390          0       522.41      0  monemodiase              2.7
# 1024658          0       509.16      0  monemodiase              2.7
# 1025257          0       554.49      0  monemodiase              2.7
# ...            ...          ...    ...          ...              ...
# 13901386         0       507.21      0  monemodiase              2.7
# 13904984         0       506.67      0  monemodiase              2.7
# 13906108         0       507.17      0  monemodiase              2.7
# 13909780         0       549.42      0  monemodiase              2.7
# 13909851         0       554.37      0  monemodiase              2.7
#
# [9224 rows x 11 columns]

# %%
df_filtered1.groupby(["rejected"]).count()
# Out:
#            tx_date  pharmacy  diagnosis       bin      pcn    group  \
# rejected
# 0         10656338  10656338   10656338  10656338  7943221  7654870
#
#           patient_pay     brand  drug_name  log_patient_pay
# rejected
# 0            10656338  10656338   10656338         10656338

# %%
NoJan_df1.groupby(["rejected", "patient_pay"]).count()
# Out:
#                       tx_date  pharmacy  diagnosis     bin     pcn   group  \
# rejected patient_pay
# 0        3.40            1844      1844       1844    1844    1844       0
#          3.45           17319     17319      17319   17319    1614   17319
#          3.47            7439      7439       7439    7439    7439    7439
#          3.50           10454     10454      10454   10454    1831   10454
#          4.00            1531      1531       1531    1531    1531    1531
# ...                       ...       ...        ...     ...     ...     ...
#          557.80             6         6          6       6       6       6
#          557.81            15        15         15      15      15      15
#          557.86            23        23         23      23      23      23
#          557.93             2         2          2       2       2       2
# 1        0.00          972854    972854     972854  972854  701839  713537
#
#                        brand  drug_name  log_patient_pay
# rejected patient_pay
# 0        3.40           1844       1844             1844
#          3.45          17319      17319            17319
#          3.47           7439       7439             7439
#          3.50          10454      10454            10454
#          4.00           1531       1531             1531
# ...                      ...        ...              ...
#          557.80            6          6                6
#          557.81           15         15               15
#          557.86           23         23               23
#          557.93            2          2                2
# 1        0.00         972854     972854           972854
#
# [20436 rows x 9 columns]
