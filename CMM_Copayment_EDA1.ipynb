# %% [markdown]
# # Initial EDA for the CoverMyMeds Corporate Project

# %% [markdown]
# Start by importing the libraries I will need

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

# %% [markdown]
# import data

# %%
cmm_data = pd.read_csv('../pharmacy_tx.csv')

# %%
cmm_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13910244 entries, 0 to 13910243
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   tx_date      object
#  1   pharmacy     object
#  2   diagnosis    object
#  3   drug         object
#  4   bin          int64
#  5   pcn          object
#  6   group        object
#  7   rejected     bool
#  8   patient_pay  float64
# dtypes: bool(1), float64(1), int64(1), object(6)
# memory usage: 862.3+ MB

# %% [markdown]
# Data has a significant number of duplicate entries. Clean data by removing duplicates

# %%
cmm_data_no_dups = cmm_data.drop_duplicates()

# %%
cmm_data_no_dups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12561845 entries, 0 to 13910243
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   tx_date      object
#  1   pharmacy     object
#  2   diagnosis    object
#  3   drug         object
#  4   bin          int64
#  5   pcn          object
#  6   group        object
#  7   rejected     bool
#  8   patient_pay  float64
# dtypes: bool(1), float64(1), int64(1), object(6)
# memory usage: 874.5+ MB

# %%
len(cmm_data)-len(cmm_data_no_dups)
# Out:
# 1348399

# %% [markdown]
# ### Create train/test split

# %%
cmm_train, cmm_test = train_test_split(cmm_data_no_dups, shuffle=True, 
                             random_state= 614, test_size=0.2)

# %%
cmm_train.head()
# Out:
#              tx_date      pharmacy diagnosis                  drug     bin  \
# 3962160   2022-04-23  Pharmacy #29    M31.63        branded mamate  322463
# 1161541   2022-02-06   Pharmacy #7    Z20.23    branded vivafastat  725700
# 10643305  2022-10-12   Pharmacy #4    U41.19    generic foxivelule  322463
# 10629491  2022-10-11  Pharmacy #31    K87.68  generic ribosatharin  664344
# 10928718  2022-10-18   Pharmacy #6    G99.93       generic simarol   96934
#
#               pcn         group  rejected  patient_pay
# 3962160   3O71UTS           NaN     False        25.75
# 1161541    327CKV  IOEAN1DWVV3Y     False       180.52
# 10643305  3O71UTS           NaN     False        12.22
# 10629491    YFVIA  AJK5MZ25T9IA     False        12.37
# 10928718  S76J7V6           NaN     False        13.93

# %% [markdown]
# ### Explore Data

# %% [markdown]
# #### Create a new column for private vs employer based insurance

# %%
cmm_train['private'] = cmm_train.group.isna().astype(int)

# %%
cmm_train.sample(10)
# Out:
#              tx_date      pharmacy diagnosis                drug     bin  \
# 11405101  2022-10-31  Pharmacy #13    V97.67  generic tanoclolol  691847
# 9846278   2022-09-21  Pharmacy #21    Q85.91   generic cupitelol  664344
# 10413938  2022-10-07  Pharmacy #11    Z20.23  branded vivafastat  757349
# 7611401   2022-07-27  Pharmacy #41    U27.71      branded sorine  664344
# 10485280  2022-10-08   Pharmacy #1    P07.55     branded sacrode  322463
# 11005931  2022-10-19   Pharmacy #5    W50.87   branded cupitelol  757349
# 11539288  2022-11-03  Pharmacy #21    G99.93     branded hozirol  757349
# 5918526   2022-06-15  Pharmacy #52    U41.19  generic foxivelule  664344
# 6976752   2022-07-13  Pharmacy #45    M06.85   branded fazipilin  725700
# 9176371   2022-09-07  Pharmacy #52    W50.87       generic lalol  664344
#
#               pcn          group  rejected  patient_pay  private
# 11405101     ZQPX  KZWQDIHCLLHD1     False         6.94        0
# 9846278       NaN    52H8KH0F83K     False         6.10        0
# 10413938   MSCXSG        DGLGRYP      True         0.00        0
# 7611401      BIZF      QK6BI1N61     False        19.45        0
# 10485280  3O71UTS            NaN     False        29.39        1
# 11005931   MSCXSG        DGLGRYP     False        17.56        0
# 11539288   MSCXSG        DGLGRYP     False        17.56        0
# 5918526      TPJD            NaN     False        19.82        1
# 6976752    327CKV   IOEAN1DWVV3Y     False        88.69        0
# 9176371      BIZF      QK6BI1N61     False        11.62        0

# %% [markdown]
# #### What can we learn from the insurance type?

# %%
cmm_train.groupby('private')['patient_pay'].describe()
# Out:
#              count       mean        std  min    25%    50%    75%     max
# private
# 0        7230590.0  23.568333  39.849623  0.0   7.99  12.60  18.67  557.93
# 1        2818886.0  27.015524  42.746789  0.0  10.22  13.93  20.74  543.40

# %% [markdown]
# A significant portion of the data set has private insurance and in general pay slightly more for their medication.

# %% [markdown]
# #### The rejected column may contain useful information but we should be careful about incorporating the cases in which rejected is True

# %%
cmm_train_nr = cmm_train[cmm_train['rejected']==False]

# %%
cmm_train_nr.groupby('private')['patient_pay'].describe()
# Out:
#              count       mean        std   min    25%    50%    75%     max
# private
# 0        6614857.0  25.762153  40.979148  3.45  10.01  14.11  19.19  557.93
# 1        2594928.0  29.347128  43.778626  3.40  10.72  13.99  22.10  543.40

# %% [markdown]
# #### Lets get some better info from the drug name

# %%
def is_it_generic(text):
    if text.split()[0] == 'generic':
        return 1
    else:
        return 0

# %%
def drug_name(text):
    return text.split()[1]

# %%
cmm_train['generic'] = cmm_train.drug.apply(is_it_generic)

# %%
cmm_train['name'] = cmm_train['drug'].apply(drug_name)

# %%
cmm_train.sample(10)
# Out:
#              tx_date      pharmacy diagnosis                     drug     bin  \
# 4958181   2022-05-20  Pharmacy #17    H36.57          branded antimab  725700
# 3899193   2022-04-22  Pharmacy #16    H60.83       branded colifunene  322463
# 1488539   2022-02-14  Pharmacy #13    I68.27             branded mule  664344
# 4403704   2022-05-07  Pharmacy #22    Z98.86  branded thiostasteglume  725700
# 4080404   2022-04-26  Pharmacy #26    I38.43           branded mamate  691847
# 8246090   2022-08-14  Pharmacy #25    W50.87       branded tanoclolol  664344
# 5980055   2022-06-17  Pharmacy #51    Z66.42         branded diadaric  691847
# 2045967   2022-03-01  Pharmacy #48    M42.24        branded semufolic  160389
# 4349313   2022-05-06  Pharmacy #36    W50.87        branded pucomalol  757349
# 10852958  2022-10-16   Pharmacy #6    I68.27         generic prazinib  322463
#
#               pcn          group  rejected  patient_pay  private  generic  \
# 4958181      1UQC            NaN     False        17.05        1        0
# 3899193       NaN        HO8HUGL     False        10.54        0        0
# 1488539    REGLCC  BH2Q8B3GY2GAV      True         0.00        0        0
# 4403704    327CKV   IOEAN1DWVV3Y     False        21.04        0        0
# 4080404     NC7EN            NaN      True         0.00        1        0
# 8246090      TPJD            NaN     False        19.82        1        0
# 5980055      2TIC    XK8RM5E75ZW     False        15.02        0        0
# 2045967     RB7UU       RS5RB3YA     False        57.67        0        0
# 4349313    MSCXSG        DGLGRYP     False        17.56        0        0
# 10852958  3O71UTS            NaN     False        10.72        1        1
#
#                      name
# 4958181           antimab
# 3899193        colifunene
# 1488539              mule
# 4403704   thiostasteglume
# 4080404            mamate
# 8246090        tanoclolol
# 5980055          diadaric
# 2045967         semufolic
# 4349313         pucomalol
# 10852958         prazinib

# %% [markdown]
# Generic drugs are generally cheaper. Branded drugs are represented at a higher rate in the data set.

# %%
cmm_train.groupby('generic')['patient_pay'].describe()
# Out:
#              count       mean        std  min    25%    50%    75%     max
# generic
# 0        6341534.0  32.116867  49.543950  0.0  10.54  16.29  27.68  557.93
# 1        3707942.0  11.568800   5.277187  0.0   7.39  10.72  15.47   63.25

# %%
cmm_train_nr.groupby('generic')['patient_pay'].describe()
# Out:
#              count       mean        std   min    25%    50%    75%     max
# generic
# 0        5520422.0  36.893955  51.414560  4.26  12.32  17.37  37.07  557.93
# 1        3689363.0  11.627058   5.226047  3.40   7.43  10.72  15.47   63.25

# %% [markdown]
# Generic drugs are rejected sometimes but not at the same rate as branded drugs

# %%
plt.figure(figsize=(18,6))

sns.stripplot(x='drug', y='patient_pay', 
                data=cmm_train_nr, alpha=0.4, color = "blue")
plt.ylabel('Patient Pay')
plt.xlabel('Drug Name')
plt.xticks(rotation=90)
plt.title('Patient Pay by Drug')
    
plt.show()

# %% [markdown]
# I like this plot to show the general difference between branded and generic drug costs.  Increasing the sample size may be something to play around with.

# %%
sample_size = 100000
sample = np.random.randint(0, len(cmm_train_nr), sample_size)

plt.figure(figsize=(8,6))

sns.stripplot(x='generic', y='patient_pay', data=cmm_train_nr.iloc[sample], alpha=0.4)
plt.ylabel('Patient Pay')
plt.xlabel('Generic')

plt.show()

# %%
sample_size = 1000000
sample = np.random.randint(0, len(cmm_train_nr), sample_size)

plt.figure(figsize=(8,6))

sns.stripplot(x='generic', y='patient_pay', data=cmm_train_nr.iloc[sample], alpha=0.4)
plt.ylabel('Patient Pay')
plt.xlabel('Generic')

plt.show()

# %%
plt.figure(figsize=(8,6))

sns.stripplot(x='generic', y='patient_pay', data=cmm_train_nr, alpha=0.4)
plt.ylabel('Patient Pay')
plt.xlabel('Generic')

plt.show()

# %% [markdown]
# I find the gap in drug price at ~375 to ~400 interesting.

# %% [markdown]
# #### Why is there a difference in price between generic and brand drugs

# %%
cmm_train_nr.name.value_counts()
# Out:
# prazinib        919151
# rulfalol        531018
# pucomalol       406629
# tanoclolol      381064
# foxivelule      367822
#                  ...
# dusin             5937
# sizubesin         4590
# gohevitravir      3248
# lehydrome         1405
# nenizevir          610
# Name: name, Length: 77, dtype: int64

# %%
cmm_train_nr.groupby('generic')['name'].value_counts()[0]
# Out:
# name
# prazinib        456110
# rulfalol        264418
# mule            262241
# hidizuzunib     224060
# tocilic         222058
#                  ...
# fumiluric         5621
# sizubesin         4590
# lehydrome         1405
# gohevitravir      1393
# nenizevir          610
# Name: name, Length: 77, dtype: int64

# %%
cmm_train_nr.groupby('generic')['name'].value_counts()[1]
# Out:
# name
# prazinib           463041
# rulfalol           266600
# pucomalol          218423
# tanoclolol         204525
# foxivelule         191193
# glycontazepelol    186602
# dienulol           163568
# ratin              137546
# tovane             127179
# cupitelol          118473
# oxasoted           115982
# momudobatin        109868
# lalol              101091
# keglusited         100796
# colifunene          94912
# gorol               87837
# bovirol             83910
# simarol             77874
# tafistitrisin       74736
# cibroniudosin       71087
# hozirol             68981
# ribosatharin        64821
# glulune             60801
# vocopirin           56808
# sorine              56436
# suvinicuvir         55028
# cycloxasonol        52603
# colade              49985
# brede               48176
# hivir               44694
# satrade             44177
# cicrochoric         38311
# lixegimoric         19118
# todiadianic         13120
# thiostasteglume     11248
# fumiluric            7958
# gohevitravir         1855
# Name: name, dtype: int64

# %% [markdown]
# All of the drugs have a branded version and the above list have both branded and generic

# %%
def plot_generic_brand(X):
    plt.figure(figsize=(8,6))

    sns.stripplot(x='generic', y='patient_pay', 
                  data=cmm_train_nr[cmm_train_nr['name']==X], alpha=0.4)
    plt.ylabel('Patient Pay')
    plt.xlabel('Generic')
    plt.title(X)
    
    plt.show()
    
    return

# %%
for X in cmm_train_nr[cmm_train_nr.generic==1]['name'].unique():
    plot_generic_brand(X)

# %%
generics = cmm_train_nr[cmm_train_nr.generic==1]['name'].unique()

# %%
plt.figure(figsize=(18,6))

sns.stripplot(x='name', y='patient_pay', 
                data=cmm_train_nr[cmm_train_nr.name.isin(generics)], alpha=0.4, hue='generic')
plt.ylabel('Patient Pay')
plt.xlabel('Drug')
plt.xticks(rotation=60)
plt.title('Generics')
    
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.stripplot(x='name', y='patient_pay', 
                data=cmm_train_nr[cmm_train_nr.name.isin(generics)], alpha=0.4)
plt.ylabel('Patient Pay')
plt.xlabel('Drug')
plt.xticks(rotation=60)
plt.title('Generics')
    
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.stripplot(x='name', y='patient_pay', 
                data=cmm_train_nr[~cmm_train_nr.name.isin(generics)], alpha=0.4)
plt.ylabel('Patient Pay')
plt.xlabel('Drug')
plt.xticks(rotation=60)
plt.title('Only Branded')
    
plt.show()

# %%
cmm_train_nr.groupby('name')['patient_pay'].describe()
# Out:
#                    count        mean        std    min     25%     50%  \
# name
# antimab         206984.0   18.770343   7.514909   5.16   16.46   19.66
# bovirol         156123.0   11.251760   3.866515   5.95    7.80   10.33
# brede            90303.0   11.471545   3.692744   6.71    8.24   10.33
# choxestamenium   59348.0  124.096780  49.976164  15.02  131.10  145.93
# cibroniudosin   138309.0   13.129981   3.805532   5.59   10.77   12.74
# ...                  ...         ...        ...    ...     ...     ...
# tovane          243513.0   11.165066   3.014642   5.22    9.42    9.57
# tricatripride    24741.0   30.809864   8.364274   7.76   27.22   31.96
# tugesutin        56170.0  161.216519  70.057548  15.02  142.63  194.00
# vivafastat       29191.0  150.976812  61.093757  15.02  157.77  176.69
# vocopirin        96721.0   18.380615   8.180048   5.16   11.41   17.58
#
#                    75%     max
# name
# antimab          21.86   42.85
# bovirol          13.93   20.56
# brede            13.93   20.05
# choxestamenium  152.99  188.02
# cibroniudosin    17.11   19.82
# ...                ...     ...
# tovane           13.05   19.82
# tricatripride    36.81   47.48
# tugesutin       208.88  261.19
# vivafastat      187.78  227.62
# vocopirin        25.90   33.89
#
# [77 rows x 8 columns]
