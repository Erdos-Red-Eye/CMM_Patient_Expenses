# %% [markdown]
# # Predicting rejection or acceptance of the claims

# %%
# import libraries
import pandas as pd
import numpy as np

import matplotlib, matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the data
rowdata_df = pd.read_csv("../pharmacy_tx.csv")

# %%
print(rowdata_df.shape)
rowdata_df.head(100)
# Out:
# (13910244, 9)
#        tx_date      pharmacy diagnosis                drug     bin      pcn  \
# 0   2022-01-02   Pharmacy #6    G99.93  branded tanoclolol  725700     1UQC
# 1   2022-01-02  Pharmacy #42    U60.52    branded oxasoted  664344      NaN
# 2   2022-01-02  Pharmacy #37    Q85.91   branded cupitelol  725700     1UQC
# 3   2022-01-02  Pharmacy #30    U60.52    generic oxasoted  571569    KB38N
# 4   2022-01-02  Pharmacy #18    N55.01      branded mamate  664344      NaN
# ..         ...           ...       ...                 ...     ...      ...
# 95  2022-01-02  Pharmacy #26    Q85.91    generic rulfalol  322463    T52GV
# 96  2022-01-02  Pharmacy #15    I68.27    branded prazinib  322463  3O71UTS
# 97  2022-01-02   Pharmacy #1    I68.27        branded mule   96934     9D24
# 98  2022-01-02  Pharmacy #49    U60.52  generic foxivelule  322463      NaN
# 99  2022-01-02  Pharmacy #13    P07.55     branded tocilic  539437      NaN
#
#           group  rejected  patient_pay
# 0           NaN     False        13.39
# 1   52H8KH0F83K     False         7.02
# 2           NaN     False        13.39
# 3        6BYJBW     False        10.84
# 4       ZX2QUWR     False        47.00
# ..          ...       ...          ...
# 95       EVD4X5     False         4.63
# 96          NaN     False        12.22
# 97   VC81HUO7ZD      True         0.00
# 98      HO8HUGL     False         5.95
# 99        1CAHL     False        55.49
#
# [100 rows x 9 columns]

# %%
rowdata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13910244 entries, 0 to 13910243
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   tx_date      object
#  1   pharmacy     object
#  2   diagnosis    object
#  3   drug         object
#  4   bin          int64
#  5   pcn          object
#  6   group        object
#  7   rejected     bool
#  8   patient_pay  float64
# dtypes: bool(1), float64(1), int64(1), object(6)
# memory usage: 862.3+ MB

# %%
#rowdata_dropna_df=rowdata_df.dropna()
print(rowdata_df.shape)
# Out:
# (13910244, 9)

# %%
duplicate = rowdata_df[rowdata_df.duplicated()]

# %%
# number of duplicates in the raw data,
print(duplicate.shape)
# Out:
# (1348399, 9)

# %%
# drop duplicates if all columns matched
dropduplicate_df= rowdata_df.drop_duplicates()
print(dropduplicate_df.shape)
# Out:
# (12561845, 9)

# %%
# split drug into two new columns brand and drug_name 
dropduplicate_df[['brand', 'drug_name']] =dropduplicate_df.drug.str.split(expand=True)
# Out:
# /Users/dilhumarablat/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
# drop the drug column 
dropduplicate_df.drop(["drug"], axis =1, inplace =True)
dropduplicate_df.head(5)
# Out:
# /Users/dilhumarablat/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       tx_date      pharmacy diagnosis     bin    pcn        group  rejected  \
# 0  2022-01-02   Pharmacy #6    G99.93  725700   1UQC          NaN     False
# 1  2022-01-02  Pharmacy #42    U60.52  664344    NaN  52H8KH0F83K     False
# 2  2022-01-02  Pharmacy #37    Q85.91  725700   1UQC          NaN     False
# 3  2022-01-02  Pharmacy #30    U60.52  571569  KB38N       6BYJBW     False
# 4  2022-01-02  Pharmacy #18    N55.01  664344    NaN      ZX2QUWR     False
#
#    patient_pay    brand   drug_name
# 0        13.39  branded  tanoclolol
# 1         7.02  branded    oxasoted
# 2        13.39  branded   cupitelol
# 3        10.84  generic    oxasoted
# 4        47.00  branded      mamate

# %%
# removing the claims in Janurary, because the Janurary is the momth most of the patient not met their diductable
NoJan_df = dropduplicate_df[dropduplicate_df['tx_date'] >= "2022-02-01"]
print(NoJan_df.shape)
# Out:
# (11629192, 10)

# %%
# check the columns in the new dataset
NoJan_df.columns.tolist()
# Out:
# ['tx_date',
#  'pharmacy',
#  'diagnosis',
#  'bin',
#  'pcn',
#  'group',
#  'rejected',
#  'patient_pay',
#  'brand',
#  'drug_name']

# %% [markdown]
# #### We have cleaned our dataset by dropping duplicates, and Janurary claims.
# Now we can start feature engineering for our model. As we see in the rejected and accepted claims in the dataset which is unbalanced data, so we need to choose a model which can deal with unbalanced data.

# %%
# see the rejected and accepted claims
NoJan_df.groupby(["rejected"]).count()
# Out:
#            tx_date  pharmacy  diagnosis       bin      pcn    group  \
# rejected
# False     10656338  10656338   10656338  10656338  7943221  7654870
# True        972854    972854     972854    972854   701839   713537
#
#           patient_pay     brand  drug_name
# rejected
# False        10656338  10656338   10656338
# True           972854    972854     972854

# %% [markdown]
# # Balanced Random Forest Classifier which can deal with unbalanced data
# In this section, we train a Balanced Random Forest Classifier to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Print the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the imbalanced_classification_report from imbalanced-learn.
# 5. Print the feature importance sorted in descending order (most important feature to least important) along with the feature score

# %%
# Initial imports
from collections import Counter
from pathlib import Path
import plotly.express as px
# Import dependencies
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from seaborn import set_style
set_style("whitegrid")

# %%
# getting columns contains strings which we need to engineer for the model
df_str_columns = NoJan_df.select_dtypes(include=['object'])
for col in df_str_columns.columns:
    print(col)
# Out:
# tx_date
# pharmacy
# diagnosis
# pcn
# group
# brand
# drug_name

# %% [markdown]
# ## Feature engineering
# First we encoded binary data such as brand (branded, generic) and rejected (false or true) into 1 or 0 as numeric. Then, we have 6 columns are not numerical but categorical data, we need to get dummies from these columns for the model. Finally, we dropped target column (rejected) along with other columns tx_date and patient_pay. We dropped patient_pay because we have 0 payment for rejected claims which is independent feature that we can not use to train or model.

# %%
# using lableEncoder to assign brand and rejected into numerical values 
le = LabelEncoder()
NoJan_df1 = NoJan_df.copy()
NoJan_df1['brand'] = le.fit_transform(NoJan_df1['brand'])
NoJan_df1['rejected'] = le.fit_transform(NoJan_df1['rejected'])

# %%
# Create our features and get dummies
X = pd.get_dummies(NoJan_df1, columns= ["diagnosis", "pcn","group", 
                                 "drug_name"]).drop(["rejected","tx_date","pharmacy","patient_pay"],axis=1)

# Create our target
y = NoJan_df1['rejected']
X.head()
# Out:
#             bin  brand  diagnosis_A00.82  diagnosis_A13.39  diagnosis_A14.01  \
# 1019813  691847      1                 0                 0                 0
# 1019814  322463      0                 0                 0                 0
# 1019815  691847      1                 0                 0                 0
# 1019816  160389      0                 0                 0                 0
# 1019817  322463      1                 0                 0                 0
#
#          diagnosis_A22.87  diagnosis_A45.07  diagnosis_B03.27  \
# 1019813                 0                 0                 0
# 1019814                 0                 0                 0
# 1019815                 0                 0                 0
# 1019816                 0                 0                 0
# 1019817                 0                 0                 0
#
#          diagnosis_B05.36  diagnosis_B42.10  ...  drug_name_tanoclolol  \
# 1019813                 0                 0  ...                     0
# 1019814                 0                 0  ...                     1
# 1019815                 0                 0  ...                     0
# 1019816                 0                 0  ...                     0
# 1019817                 0                 0  ...                     0
#
#          drug_name_thiostasteglume  drug_name_tocilic  drug_name_tocrocin  \
# 1019813                          0                  0                   0
# 1019814                          0                  0                   0
# 1019815                          0                  0                   0
# 1019816                          0                  0                   0
# 1019817                          0                  0                   0
#
#          drug_name_todiadianic  drug_name_tovane  drug_name_tricatripride  \
# 1019813                      0                 0                        0
# 1019814                      0                 0                        0
# 1019815                      0                 0                        0
# 1019816                      0                 0                        0
# 1019817                      0                 0                        0
#
#          drug_name_tugesutin  drug_name_vivafastat  drug_name_vocopirin
# 1019813                    0                     0                    0
# 1019814                    0                     0                    0
# 1019815                    0                     0                    0
# 1019816                    0                     0                    0
# 1019817                    0                     0                    0
#
# [5 rows x 308 columns]

# %%
# Check the balance of our target values, 0 is accepted claims and 1 is the rejected
y.value_counts()
# Out:
# 0    10656338
# 1      972854
# Name: rejected, dtype: int64

# %%
# Import train test split function
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1,  train_size=0.25)

# %%
# Check balances and they are not balanced 
print(Counter(y_train))
print(Counter(y_test))
# Out:
# Counter({0: 2664575, 1: 242723})
# Counter({0: 7991763, 1: 730131})

# %% [markdown]
# ## Resample the training data with the BalancedRandomForestClassifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
# get time for execustion
from datetime import datetime
start_time = datetime.now()

from imblearn.ensemble import BalancedRandomForestClassifier
BalancedRFC_model = BalancedRandomForestClassifier(n_estimators=40, random_state=1)
BalancedRFC_model= BalancedRFC_model.fit(X_train, y_train)

end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Duration: 0:06:25.774033

# %%
# Calculated the balanced accuracy score with test data
from datetime import datetime
start_time = datetime.now()

y_pred = BalancedRFC_model.predict(X_test)
from sklearn.metrics import balanced_accuracy_score
balanced_accuracy_score(y_test, y_pred)

end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Duration: 0:04:58.626180

# %%
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.8775124716572094

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0      6052391      1939372
# Actual 1         1682       728449

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      0.76      1.00      0.86      0.87      0.74   7991763
#           1       0.27      1.00      0.76      0.43      0.87      0.77    730131
#
# avg / total       0.94      0.78      0.98      0.83      0.87      0.74   8721894

# %%
# List the features 
features = BalancedRFC_model.feature_importances_
features
# Out:
# array([1.67649344e-02, 2.02886935e-01, 1.75653686e-06, 1.41521298e-04,
#        2.17113130e-04, 3.28274420e-06, 5.36909336e-05, 2.69894023e-04,
#        3.39272539e-04, 1.25483626e-04, 3.38127689e-03, 8.63659417e-05,
#        5.09049111e-05, 4.39041636e-04, 1.40508882e-06, 3.05871085e-04,
#        1.28983731e-05, 1.07424619e-04, 1.31620169e-05, 6.87931734e-05,
#        1.07188106e-05, 2.08928615e-05, 4.37197649e-06, 8.01322880e-04,
#        1.24265501e-03, 2.96497461e-05, 2.82650203e-04, 4.87468452e-04,
#        2.78572443e-04, 0.00000000e+00, 2.92939175e-05, 4.40615438e-05,
#        1.68022024e-05, 1.47082117e-05, 2.85853584e-05, 1.61238176e-06,
#        2.52373995e-03, 4.13387257e-05, 2.81816678e-04, 2.92715897e-02,
#        1.74244615e-05, 1.68109766e-06, 3.51585905e-04, 4.45587914e-03,
#        1.89237869e-04, 1.05564330e-04, 1.00782917e-04, 7.39028328e-04,
#        2.97898451e-04, 2.20756126e-05, 6.05979854e-06, 7.00007651e-04,
#        4.93168916e-06, 8.79797816e-04, 1.38314018e-02, 8.74362384e-05,
#        7.19639053e-04, 7.90699369e-05, 0.00000000e+00, 4.66953996e-02,
#        1.49164044e-05, 2.72678046e-03, 1.08189963e-04, 1.44508952e-04,
#        1.41371370e-04, 4.34233748e-04, 1.96394751e-03, 2.73989891e-06,
#        8.81895482e-05, 2.16327822e-03, 1.84071497e-08, 9.95117680e-05,
#        6.18318472e-07, 2.23620339e-04, 1.51493362e-06, 3.15208078e-04,
#        2.06475747e-04, 1.64987362e-04, 6.15463852e-05, 2.49774835e-04,
#        7.61759667e-04, 1.93336718e-03, 5.76727300e-05, 1.39253522e-05,
#        2.80869136e-04, 5.35214745e-05, 2.37343471e-04, 2.42112036e-06,
#        2.03235063e-03, 6.18313715e-04, 1.30057184e-04, 1.45930084e-02,
#        1.07333948e-03, 1.46451215e-05, 1.12875552e-04, 3.14080722e-05,
#        5.04413738e-05, 3.94649896e-04, 1.02227783e-05, 6.66633216e-06,
#        3.52997562e-04, 0.00000000e+00, 1.10882238e-03, 1.33568373e-03,
#        5.05541825e-03, 8.80340995e-04, 3.73654008e-04, 2.16576233e-06,
#        7.39761680e-06, 1.55881168e-03, 9.67949317e-05, 1.85953641e-03,
#        2.94582952e-05, 6.72988894e-06, 4.37451369e-05, 1.13978427e-04,
#        1.47200382e-04, 1.90574300e-02, 6.09710531e-06, 6.59547405e-05,
#        2.05245586e-06, 1.56086984e-04, 5.50786522e-05, 5.43868399e-04,
#        1.11088764e-06, 2.20983279e-03, 6.23594594e-04, 2.98346590e-05,
#        3.59210342e-06, 2.80710194e-03, 6.55618421e-04, 2.57403135e-04,
#        9.69955887e-03, 8.61361928e-05, 3.49530044e-04, 2.37192993e-03,
#        9.38373138e-04, 1.74636148e-03, 2.77962546e-04, 5.50580123e-03,
#        1.38099385e-03, 2.05825405e-03, 1.73939091e-03, 3.35261054e-04,
#        1.11849757e-03, 8.94989979e-04, 6.80719040e-04, 3.82223462e-04,
#        3.14861037e-04, 3.61817575e-04, 1.74524928e-03, 3.35640300e-03,
#        1.68665686e-04, 7.32712992e-04, 7.66784149e-04, 1.81340627e-04,
#        1.99353677e-03, 8.64560309e-04, 3.36918586e-04, 1.42941230e-03,
#        1.62140129e-03, 1.40751920e-03, 2.68222327e-04, 4.20336212e-04,
#        5.36576055e-04, 3.08995385e-04, 1.40133951e-03, 1.07926456e-03,
#        1.37123424e-03, 2.56230423e-03, 1.49803205e-03, 1.76992238e-03,
#        1.21766999e-03, 1.77348133e-03, 4.86365512e-04, 1.20779590e-03,
#        5.51665683e-04, 1.26475932e-03, 5.76418831e-04, 1.85791737e-03,
#        9.54442836e-04, 4.74377863e-04, 5.48306633e-04, 1.23824235e-03,
#        9.92691572e-04, 2.80358060e-03, 1.66827637e-04, 4.06736949e-03,
#        2.30047767e-03, 1.50741729e-03, 3.81606035e-04, 2.85918592e-04,
#        5.93201903e-04, 2.72998506e-04, 5.54146139e-04, 1.70650787e-03,
#        1.17788164e-03, 1.73725200e-03, 2.07185286e-03, 1.62671150e-03,
#        6.77916658e-04, 5.63058948e-04, 2.28199479e-04, 7.78424566e-03,
#        3.97806669e-04, 1.08659816e-03, 6.61441979e-04, 2.10689925e-03,
#        7.26305956e-04, 4.84256132e-04, 1.62868781e-03, 9.46903939e-04,
#        5.47381450e-04, 1.75976314e-04, 3.81340621e-04, 1.34261167e-03,
#        1.23295786e-03, 3.11022177e-04, 1.20151780e-03, 2.99429030e-03,
#        1.13175581e-03, 9.55655062e-04, 8.37015299e-04, 5.16220457e-04,
#        1.30982808e-03, 1.04016067e-03, 2.69217597e-04, 2.28494647e-03,
#        1.48782886e-03, 2.82362053e-04, 1.69844053e-03, 1.86332638e-02,
#        3.93528040e-03, 3.38033304e-03, 4.53345810e-03, 4.23357539e-03,
#        5.97529746e-03, 6.94229757e-03, 1.47565950e-03, 9.51377551e-03,
#        1.07005076e-03, 2.76864431e-03, 8.28555199e-04, 1.91029974e-04,
#        8.62780141e-03, 1.24258328e-02, 1.84560622e-04, 1.63146926e-03,
#        1.47454688e-03, 1.81347682e-03, 2.70177405e-02, 3.52915676e-04,
#        2.57630824e-04, 1.62624181e-03, 9.70861690e-03, 2.23857496e-03,
#        1.48660949e-02, 1.15431790e-04, 8.64157703e-03, 6.00560387e-04,
#        3.21024233e-02, 3.73619541e-03, 3.48912080e-03, 3.00730048e-03,
#        6.38314327e-04, 3.26483609e-03, 7.49056879e-03, 7.21601985e-05,
#        3.18488052e-03, 2.77497833e-04, 1.05493821e-04, 6.93716640e-03,
#        6.94814771e-04, 1.69712558e-02, 1.06969681e-04, 2.92455774e-03,
#        8.30645050e-04, 1.48741529e-03, 5.64776585e-03, 1.50887336e-02,
#        1.48437028e-04, 7.98401014e-03, 1.08212025e-04, 7.29210496e-02,
#        6.56559475e-04, 8.59182710e-03, 5.44597208e-03, 1.49174452e-03,
#        2.57388849e-02, 1.12882120e-03, 2.36536641e-03, 8.11575477e-03,
#        3.67516295e-03, 2.01630353e-04, 3.61866481e-03, 2.25849462e-04,
#        8.76356932e-03, 3.80652720e-03, 1.48057172e-02, 1.04958424e-03,
#        7.01101554e-03, 2.49079673e-04, 2.18145383e-03, 1.86132776e-02,
#        9.76591758e-04, 4.63782461e-03, 1.22429883e-03, 2.45111233e-03])

# %%
# Plotting feature importance 
importances = pd.DataFrame(np.zeros((X_train.shape[1], 1)), columns=["importance"], index=X_train.columns)

importances.iloc[:,0] = BalancedRFC_model.feature_importances_

importances = importances.sort_values(by="importance", ascending=False)[:40]

plt.figure(figsize=(15, 10))
sns.barplot(x="importance", y=importances.index, data=importances,  color='steelblue')
plt.show()
plt.savefig("featureimportance.png") #save as png

# %% [markdown]
# ### try to see important features in the actual dataset

# %%
# branded 0, generic 1; rejected 1, accepted 0
NoJan_df1.groupby(["brand", "rejected"]).count()
# Out:
#                 tx_date  pharmacy  diagnosis      bin      pcn    group  \
# brand rejected
# 0     0         6385347   6385347    6385347  6385347  4764726  4584636
#       1          951222    951222     951222   951222   686963   696490
# 1     0         4270991   4270991    4270991  4270991  3178495  3070234
#       1           21632     21632      21632    21632    14876    17047
#
#                 patient_pay  drug_name
# brand rejected
# 0     0             6385347    6385347
#       1              951222     951222
# 1     0             4270991    4270991
#       1               21632      21632

# %% [markdown]
# #### as we suspected more branded drugs were rejected as compared to generic ones

# %%
prazinib_df=NoJan_df1.loc[NoJan_df1["drug_name"] == "prazinib"]
prazinib_df.head(10)
# Out:
#             tx_date      pharmacy diagnosis     bin      pcn         group  \
# 1019813  2022-02-01  Pharmacy #54    G51.87  691847    XH4T3        GOM8K0
# 1019846  2022-02-01  Pharmacy #11    I68.27  664344      NaN  STGRDKR1J5RD
# 1019854  2022-02-01  Pharmacy #30    I68.27  664344     DY4B           NaN
# 1019873  2022-02-01  Pharmacy #52    I68.27   96934  S76J7V6           NaN
# 1019882  2022-02-01  Pharmacy #17    I68.27  664344      NaN   52H8KH0F83K
# 1019893  2022-02-01  Pharmacy #56    I68.27  571569      NaN           NaN
# 1019931  2022-02-01  Pharmacy #21    I68.27   96934  S76J7V6           NaN
# 1019938  2022-02-01   Pharmacy #7    G51.87  691847    XH4T3        GOM8K0
# 1019945  2022-02-01   Pharmacy #9    I68.27  322463    T52GV        EVD4X5
# 1019967  2022-02-01  Pharmacy #27    I68.27  539437   CG3ZWQ           NaN
#
#          rejected  patient_pay  brand drug_name
# 1019813         0        10.72      1  prazinib
# 1019846         0        11.74      0  prazinib
# 1019854         0        17.11      0  prazinib
# 1019873         0        13.93      0  prazinib
# 1019882         0        10.63      1  prazinib
# 1019893         0        10.84      1  prazinib
# 1019931         0        10.44      1  prazinib
# 1019938         0        15.55      0  prazinib
# 1019945         0        10.72      1  prazinib
# 1019967         0         7.27      0  prazinib

# %% [markdown]
# ##### interesting that same drug such as prazinib was classified as generic and branded, however, their patient payment were comparable.

# %%
prazinib_df.groupby(["brand", "rejected"]).count()
# Out:
#                 tx_date  pharmacy  diagnosis     bin     pcn   group  \
# brand rejected
# 0     0          526395    526395     526395  526395  397781  380168
# 1     0          535607    535607     535607  535607  403978  386698
#
#                 patient_pay  drug_name
# brand rejected
# 0     0              526395     526395
# 1     0              535607     535607

# %%
rowdata_df.loc[rowdata_df["drug"] == "branded prazinib"]
# Out:
#              tx_date      pharmacy diagnosis              drug     bin  \
# 9         2022-01-02  Pharmacy #28    I68.27  branded prazinib  664344
# 45        2022-01-02   Pharmacy #5    G51.87  branded prazinib  664344
# 86        2022-01-02  Pharmacy #38    I68.27  branded prazinib  725700
# 96        2022-01-02  Pharmacy #15    I68.27  branded prazinib  322463
# 102       2022-01-02  Pharmacy #23    I68.27  branded prazinib   96934
# ...              ...           ...       ...               ...     ...
# 13910179  2022-12-30  Pharmacy #52    I68.27  branded prazinib  725700
# 13910204  2022-12-30  Pharmacy #57    I68.27  branded prazinib  691847
# 13910207  2022-12-30  Pharmacy #55    I68.27  branded prazinib  757349
# 13910230  2022-12-30  Pharmacy #18    I68.27  branded prazinib  322463
# 13910242  2022-12-30   Pharmacy #0    I68.27  branded prazinib   96934
#
#               pcn          group  rejected  patient_pay
# 9          CS8580            NaN     False        11.74
# 45           BIZF      QK6BI1N61     False        11.62
# 86         327CKV   IOEAN1DWVV3Y     False        11.40
# 96        3O71UTS            NaN     False        12.22
# 102       S76J7V6            NaN     False        13.93
# ...           ...            ...       ...          ...
# 13910179     1UQC            NaN     False        13.39
# 13910204    NC7EN            NaN     False        17.91
# 13910207    RM0HB  SJVO3GXUURRGO     False        10.86
# 13910230  3O71UTS            NaN     False        12.22
# 13910242  S76J7V6            NaN     False        13.93
#
# [845852 rows x 9 columns]

# %%
rowdata_df.loc[rowdata_df["drug"] == "generic prazinib"]
# Out:
#              tx_date      pharmacy diagnosis              drug     bin  \
# 14        2022-01-02  Pharmacy #24    I68.27  generic prazinib  691847
# 21        2022-01-02  Pharmacy #22    G51.87  generic prazinib  691847
# 27        2022-01-02  Pharmacy #54    I68.27  generic prazinib  725700
# 104       2022-01-02   Pharmacy #0    I68.27  generic prazinib  718350
# 105       2022-01-02  Pharmacy #30    I68.27  generic prazinib  664344
# ...              ...           ...       ...               ...     ...
# 13910178  2022-12-30   Pharmacy #8    S15.62  generic prazinib  757349
# 13910182  2022-12-30   Pharmacy #6    I68.27  generic prazinib  322463
# 13910184  2022-12-30  Pharmacy #32    G51.87  generic prazinib  571569
# 13910211  2022-12-30  Pharmacy #16    I68.27  generic prazinib  571569
# 13910236  2022-12-30  Pharmacy #32    I68.27  generic prazinib  757349
#
#              pcn          group  rejected  patient_pay
# 14         NC7EN            NaN     False        10.72
# 21          ZQPX  KZWQDIHCLLHD1     False        10.72
# 27        327CKV   IOEAN1DWVV3Y     False        10.62
# 104        J5DT8          IX6P0     False        10.59
# 105          NaN        ZX2QUWR     False        13.33
# ...          ...            ...       ...          ...
# 13910178  MSCXSG        DGLGRYP     False        10.63
# 13910182     NaN        HO8HUGL     False        10.12
# 13910184   KB38N         6BYJBW     False        10.84
# 13910211   KB38N         6BYJBW     False        10.84
# 13910236   RM0HB  SJVO3GXUURRGO     False        10.72
#
# [865905 rows x 9 columns]

# %%
NoJan_df1.groupby(["bin", "rejected"]).count()
# Out:
#                  tx_date  pharmacy  diagnosis      pcn    group  patient_pay  \
# bin    rejected
# 96934  0          640111    640111     640111   640111    75192       640111
#        1           60038     60038      60038    60038     9278        60038
# 160389 0          204641    204641     204641   204641   204641       204641
#        1           23255     23255      23255    23255    23255        23255
# 322463 0         1878945   1878945    1878945  1127791  1236430      1878945
#        1          192316    192316     192316    97860   139807       192316
# 539437 0          406455    406455     406455    62263   384984       406455
#        1           31471     31471      31471     4598    29890        31471
# 571569 0          604343    604343     604343   531913   542111       604343
#        1           45423     45423      45423    40397    41112        45423
# 664344 0         3032414   3032414    3032414  1754081  2325716      3032414
#        1          277270    277270     277270   155742   216977       277270
# 691847 0         1055787   1055787    1055787   967504   694070      1055787
#        1           95671     95671      95671    87822    63975        95671
# 718350 0          206500    206500     206500   206500   206500       206500
#        1           17014     17014      17014    17014    17014        17014
# 725700 0         1539833   1539833    1539833  1435759  1039232      1539833
#        1          135218    135218     135218   125244    90496       135218
# 756120 0          141315    141315     141315   141315        0       141315
#        1           13445     13445      13445    13445        0        13445
# 757349 0          730133    730133     730133   655482   730133       730133
#        1           60275     60275      60275    54966    60275        60275
# 956971 0          215861    215861     215861   215861   215861       215861
#        1           21458     21458      21458    21458    21458        21458
#
#                    brand  drug_name
# bin    rejected
# 96934  0          640111     640111
#        1           60038      60038
# 160389 0          204641     204641
#        1           23255      23255
# 322463 0         1878945    1878945
#        1          192316     192316
# 539437 0          406455     406455
#        1           31471      31471
# 571569 0          604343     604343
#        1           45423      45423
# 664344 0         3032414    3032414
#        1          277270     277270
# 691847 0         1055787    1055787
#        1           95671      95671
# 718350 0          206500     206500
#        1           17014      17014
# 725700 0         1539833    1539833
#        1          135218     135218
# 756120 0          141315     141315
#        1           13445      13445
# 757349 0          730133     730133
#        1           60275      60275
# 956971 0          215861     215861
#        1           21458      21458
